# %%
# ----------------------------
# BASE
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt

# ----------------------------
# TREEMAP
# pip install squarify
import squarify  

# ----------------------------
# CONFIGURATION
import warnings
warnings.filterwarnings("ignore")
warnings.simplefilter(action='ignore', category=FutureWarning)

pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:.2f}'.format

# %%
pip install squarify
# Out:
# Requirement already satisfied: squarify in /Users/venkatreddy/opt/anaconda3/lib/python3.9/site-packages (0.4.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <a id='load'></a>
# <h1 style="color:purple" >2. Data</h1>

# %%
raw9 = pd.read_excel("/Users/venkatreddy/Downloads/online_retail_II.xlsx", sheet_name = "Year 2009-2010")
raw10 = pd.read_excel("/Users/venkatreddy/Downloads/online_retail_II.xlsx", sheet_name = "Year 2010-2011")
df1 = raw9.copy()
df2 = raw10.copy()

# %%
(df1.shape, df2.shape)
# Out:
# ((525461, 8), (541910, 8))

# %%
df2
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 541905  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 541909  581587      POST                              POSTAGE         1
#
#                InvoiceDate  Price  Customer ID         Country
# 0      2010-12-01 08:26:00   2.55     17850.00  United Kingdom
# 1      2010-12-01 08:26:00   3.39     17850.00  United Kingdom
# 2      2010-12-01 08:26:00   2.75     17850.00  United Kingdom
# 3      2010-12-01 08:26:00   3.39     17850.00  United Kingdom
# 4      2010-12-01 08:26:00   3.39     17850.00  United Kingdom
# ...                    ...    ...          ...             ...
# 541905 2011-12-09 12:50:00   2.10     12680.00          France
# 541906 2011-12-09 12:50:00   4.15     12680.00          France
# 541907 2011-12-09 12:50:00   4.15     12680.00          France
# 541908 2011-12-09 12:50:00   4.95     12680.00          France
# 541909 2011-12-09 12:50:00  18.00     12680.00          France
#
# [541910 rows x 8 columns]

# %% [markdown]
# <a id='missing'></a>
# <h1 style="color:purple" >3. Missing Values</h1>

# %%
print("2009-2010")
print("Missing Frequency: \n")
print(df1.isnull().sum().sort_values(ascending = False), "\n")
print("Missing Proportion: \n")
print((df1.isnull().sum() / df1.shape[0]).sort_values(ascending = False))
print("")
print("2010-2011")
print("Missing Frequency: \n")
print(df2.isnull().sum().sort_values(ascending = False), "\n")
print("Missing Proportion: \n")
print((df2.isnull().sum() / df2.shape[0]).sort_values(ascending = False))
# Out:
# 2009-2010
# Missing Frequency:
#
# Customer ID    107927
# Description      2928
# Invoice             0
# StockCode           0
# Quantity            0
# InvoiceDate         0
# Price               0
# Country             0
# dtype: int64
#
# Missing Proportion:
#
# Customer ID   0.21
# Description   0.01
# Invoice       0.00
# StockCode     0.00
# Quantity      0.00
# InvoiceDate   0.00
# Price         0.00
# Country       0.00
# dtype: float64
#
# 2010-2011
# Missing Frequency:
#
# Customer ID    135080
# Description      1454
# Invoice             0
# StockCode           0
# Quantity            0
# InvoiceDate         0
# Price               0
# Country             0
# dtype: int64
#
# Missing Proportion:
#
# Customer ID   0.25
# Description   0.00
# Invoice       0.00
# StockCode     0.00
# Quantity      0.00
# InvoiceDate   0.00
# Price         0.00
# Country       0.00
# dtype: float64

# %%
# Remove Missing Values
df1.dropna(inplace = True)
df2.dropna(inplace = True)

# %% [markdown]
# <a id='summary'></a>
# <h1 style="color:purple" >4. Summary Stats & Outlier Values</h1>

# %%
# 2009-2010
df1.describe([0.01, 0.05, 0.10, 0.20, 0.90, 0.95, 0.99]).T
# Out:
#                 count     mean     std      min       1%       5%      10%  \
# Quantity    417534.00    12.76  101.22 -9360.00    -2.00     1.00     1.00
# Price       417534.00     3.89   71.13     0.00     0.29     0.42     0.65
# Customer ID 417534.00 15360.65 1680.81 12346.00 12435.00 12725.00 13042.00
#
#                  20%      50%      90%      95%      99%      max
# Quantity        1.00     4.00    24.00    36.00   144.00 19152.00
# Price           0.85     1.95     6.75     8.50    14.95 25111.09
# Customer ID 13624.00 15311.00 17706.00 17913.00 18196.00 18287.00

# %%
# 2010-2011
df2.describe([0.01, 0.05, 0.10, 0.20, 0.90, 0.95, 0.99]).T
# Out:
#                 count     mean     std       min       1%       5%      10%  \
# Quantity    406830.00    12.06  248.69 -80995.00    -2.00     1.00     1.00
# Price       406830.00     3.46   69.32      0.00     0.21     0.42     0.55
# Customer ID 406830.00 15287.68 1713.60  12346.00 12415.00 12626.00 12876.00
#
#                  20%      50%      90%      95%      99%      max
# Quantity        1.00     5.00    24.00    36.00   120.00 80995.00
# Price           0.85     1.95     6.75     8.50    15.00 38970.00
# Customer ID 13536.00 15152.00 17719.00 17905.00 18212.00 18287.00

# %% [markdown]
# **Remove negative values!**
#
# Negative values are returned items.

# %%
df1 = df1[~df1["Invoice"].str.contains("C", na = False)]
df2 = df2[~df2["Invoice"].str.contains("C", na = False)]

# %%
df1.describe([0.01, 0.05, 0.10, 0.20, 0.90, 0.95, 0.99]).T
# Out:
#                 count     mean     std      min       1%       5%      10%  \
# Quantity    407695.00    13.59   96.84     1.00     1.00     1.00     1.00
# Price       407695.00     3.29   34.76     0.00     0.29     0.42     0.65
# Customer ID 407695.00 15368.50 1679.80 12346.00 12435.00 12731.00 13044.00
#
#                  20%      50%      90%      95%      99%      max
# Quantity        2.00     5.00    24.00    36.00   144.00 19152.00
# Price           0.85     1.95     6.75     8.50    14.95 10953.50
# Customer ID 13635.00 15321.00 17706.00 17913.00 18196.00 18287.00

# %%
df2.describe([0.01, 0.05, 0.10, 0.20, 0.90, 0.95, 0.99]).T
# Out:
#                 count     mean     std      min       1%       5%      10%  \
# Quantity    397925.00    13.02  180.42     1.00     1.00     1.00     1.00
# Price       397925.00     3.12   22.10     0.00     0.21     0.42     0.55
# Customer ID 397925.00 15294.31 1713.17 12346.00 12415.00 12627.00 12883.00
#
#                  20%      50%      90%      95%      99%      max
# Quantity        2.00     6.00    24.00    36.00   120.00 80995.00
# Price           0.85     1.95     6.35     8.50    14.95  8142.75
# Customer ID 13552.00 15159.00 17725.00 17912.00 18211.00 18287.00

# %%
df1[["Quantity", "Price"]].boxplot();

# %%
df2[["Quantity", "Price"]].boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='rfm'></a>
# <h1 style="color:purple" >5. RFM Analysis</h1>
#
# <h2 style="color:purple" >Recency</h2>

# %%
print("2009-2010: Min Date", df1["InvoiceDate"].min(), "Max Date", df1["InvoiceDate"].max())
print("2010-2011: Min Date", df2["InvoiceDate"].min(), "Max Date", df2["InvoiceDate"].max())
# Out:
# 2009-2010: Min Date 2009-12-01 07:45:00 Max Date 2010-12-09 20:01:00
# 2010-2011: Min Date 2010-12-01 08:26:00 Max Date 2011-12-09 12:50:00

# %%
recency1 = (dt.datetime(2010, 12, 9) - df1.groupby("Customer ID").agg({"InvoiceDate":"max"})).rename(columns = {"InvoiceDate":"Recency"})
recency2 = (dt.datetime(2011, 12, 9) - df2.groupby("Customer ID").agg({"InvoiceDate":"max"})).rename(columns = {"InvoiceDate":"Recency"})

recency1["Recency"] = recency1["Recency"].apply(lambda x: x.days)
recency2["Recency"] = recency2["Recency"].apply(lambda x: x.days)

recency2.head()
# Out:
#              Recency
# Customer ID
# 12346.00         324
# 12347.00           1
# 12348.00          74
# 12349.00          17
# 12350.00         309

# %% [markdown]
# <h2 style="color:purple" >Frequency</h2>

# %%
freq1 = df1.groupby("Customer ID").agg({"InvoiceDate":"nunique"}).rename(columns={"InvoiceDate": "Frequency"})
freq2 = df2.groupby("Customer ID").agg({"InvoiceDate":"nunique"}).rename(columns={"InvoiceDate": "Frequency"})

freq2
# Out:
#              Frequency
# Customer ID
# 12346.00             1
# 12347.00             7
# 12348.00             4
# 12349.00             1
# 12350.00             1
# ...                ...
# 18280.00             1
# 18281.00             1
# 18282.00             2
# 18283.00            16
# 18287.00             3
#
# [4339 rows x 1 columns]

# %% [markdown]
# <h2 style="color:purple" >Monetary</h2>

# %%
df1["TotalPrice"] = df1["Quantity"] * df1["Price"]
df2["TotalPrice"] = df2["Quantity"] * df2["Price"]

monetary1 = df1.groupby("Customer ID").agg({"TotalPrice":"sum"}).rename(columns={"TotalPrice":"Monetary"})
monetary2 = df2.groupby("Customer ID").agg({"TotalPrice":"sum"}).rename(columns={"TotalPrice":"Monetary"})

monetary2.head()
# Out:
#              Monetary
# Customer ID
# 12346.00     77183.60
# 12347.00      4310.00
# 12348.00      1797.24
# 12349.00      1757.55
# 12350.00       334.40

# %%
rfm1 = pd.concat([recency1, freq1, monetary1],  axis=1)
rfm2 = pd.concat([recency2, freq2, monetary2],  axis=1)

rfm2.head()
# Out:
#              Recency  Frequency  Monetary
# Customer ID
# 12346.00         324          1  77183.60
# 12347.00           1          7   4310.00
# 12348.00          74          4   1797.24
# 12349.00          17          1   1757.55
# 12350.00         309          1    334.40

# %% [markdown]
# <h2 style="color:purple" >Create RFM Score</h2>

# %%
rfm1["RecencyScore"] = pd.qcut(rfm1["Recency"], 5, labels = [5, 4 , 3, 2, 1])
rfm2["RecencyScore"] = pd.qcut(rfm2["Recency"], 5, labels = [5, 4 , 3, 2, 1])

rfm1["FrequencyScore"]= pd.qcut(rfm1["Frequency"].rank(method="first"),5, labels=[1,2,3,4,5])
rfm2["FrequencyScore"]= pd.qcut(rfm2["Frequency"].rank(method="first"),5, labels=[1,2,3,4,5])

rfm1["MonetaryScore"] = pd.qcut(rfm1['Monetary'], 5, labels = [1, 2, 3, 4, 5])
rfm2["MonetaryScore"] = pd.qcut(rfm2['Monetary'], 5, labels = [1, 2, 3, 4, 5])

rfm2.head()
# Out:
#              Recency  Frequency  Monetary RecencyScore FrequencyScore  \
# Customer ID
# 12346.00         324          1  77183.60            1              1
# 12347.00           1          7   4310.00            5              5
# 12348.00          74          4   1797.24            2              4
# 12349.00          17          1   1757.55            4              1
# 12350.00         309          1    334.40            1              1
#
#             MonetaryScore
# Customer ID
# 12346.00                5
# 12347.00                5
# 12348.00                4
# 12349.00                4
# 12350.00                2

# %%
# RFM Scores: Category
rfm1["RFM_SCORE"] = (rfm1['RecencyScore'].astype(str) + 
                     rfm1['FrequencyScore'].astype(str) + 
                     rfm1['MonetaryScore'].astype(str))

rfm2["RFM_SCORE"] = (rfm2['RecencyScore'].astype(str) + 
                     rfm2['FrequencyScore'].astype(str) + 
                     rfm2['MonetaryScore'].astype(str))

rfm2.head()
# Out:
#              Recency  Frequency  Monetary RecencyScore FrequencyScore  \
# Customer ID
# 12346.00         324          1  77183.60            1              1
# 12347.00           1          7   4310.00            5              5
# 12348.00          74          4   1797.24            2              4
# 12349.00          17          1   1757.55            4              1
# 12350.00         309          1    334.40            1              1
#
#             MonetaryScore RFM_SCORE
# Customer ID
# 12346.00                5       115
# 12347.00                5       555
# 12348.00                4       244
# 12349.00                4       414
# 12350.00                2       112

# %%
seg_map = {
    r'[1-2][1-2]': 'Hibernating',
    r'[1-2][3-4]': 'At Risk',
    r'[1-2]5': 'Can\'t Loose',
    r'3[1-2]': 'About to Sleep',
    r'33': 'Need Attention',
    r'[3-4][4-5]': 'Loyal Customers',
    r'41': 'Promising',
    r'51': 'New Customers',
    r'[4-5][2-3]': 'Potential Loyalists',
    r'5[4-5]': 'Champions'
}

rfm1['Segment'] = rfm1['RecencyScore'].astype(str) + rfm1['FrequencyScore'].astype(str)
rfm1['Segment'] = rfm1['Segment'].replace(seg_map, regex=True)

rfm2['Segment'] = rfm2['RecencyScore'].astype(str) + rfm2['FrequencyScore'].astype(str)
rfm2['Segment'] = rfm2['Segment'].replace(seg_map, regex=True)

rfm2.head()
# Out:
#              Recency  Frequency  Monetary RecencyScore FrequencyScore  \
# Customer ID
# 12346.00         324          1  77183.60            1              1
# 12347.00           1          7   4310.00            5              5
# 12348.00          74          4   1797.24            2              4
# 12349.00          17          1   1757.55            4              1
# 12350.00         309          1    334.40            1              1
#
#             MonetaryScore RFM_SCORE      Segment
# Customer ID
# 12346.00                5       115  Hibernating
# 12347.00                5       555    Champions
# 12348.00                4       244      At Risk
# 12349.00                4       414    Promising
# 12350.00                2       112  Hibernating

# %% [markdown]
# <h2 style="color:purple" >Summary Statistics</h2>

# %%
rfmStats1 = rfm1[["Segment","Recency","Frequency", "Monetary"]].groupby("Segment").agg(["mean","median","count", "std"])
rfmStats1.columns = rfmStats1.columns.map('_'.join).str.strip('|')
rfmStats1
# Out:
#                      Recency_mean  Recency_median  Recency_count  Recency_std  \
# Segment
# About to Sleep              51.85           51.00            343        10.26
# At Risk                    149.94          128.00            611        69.98
# Can't Loose                121.72          106.50             78        49.72
# Champions                    5.12            5.00            663         4.62
# Hibernating                212.31          211.00           1016        89.78
# Loyal Customers             34.28           29.00            743        16.06
# Need Attention              51.21           51.00            207         9.84
# New Customers                6.58            6.50             50         4.31
# Potential Loyalists         16.77           17.00            516         9.73
# Promising                   23.76           23.00             87         6.03
#
#                      Frequency_mean  Frequency_median  Frequency_count  \
# Segment
# About to Sleep                 1.20              1.00              343
# At Risk                        3.07              3.00              611
# Can't Loose                    9.04              7.50               78
# Champions                     12.50              8.00              663
# Hibernating                    1.13              1.00             1016
# Loyal Customers                6.82              5.00              743
# Need Attention                 2.45              2.00              207
# New Customers                  1.00              1.00               50
# Potential Loyalists            2.02              2.00              516
# Promising                      1.00              1.00               87
#
#                      Frequency_std  Monetary_mean  Monetary_median  \
# Segment
# About to Sleep                0.40         442.27           317.76
# At Risk                       1.09        1188.21           760.19
# Can't Loose                   5.78        4072.97          2316.49
# Champions                    17.19        6852.26          2508.32
# Hibernating                   0.33         401.98           250.16
# Loyal Customers               4.38        2743.48          1818.71
# Need Attention                0.50        1058.79           730.47
# New Customers                 0.00         386.20           258.82
# Potential Loyalists           0.70         729.16           523.66
# Promising                     0.00         368.02           293.74
#
#                      Monetary_count  Monetary_std
# Segment
# About to Sleep                  343        417.30
# At Risk                         611       1844.17
# Can't Loose                      78       5275.40
# Champions                       663      21556.38
# Hibernating                    1016        775.08
# Loyal Customers                 743       3255.11
# Need Attention                  207       1190.26
# New Customers                    50        493.32
# Potential Loyalists             516        837.55
# Promising                        87        343.91

# %%
rfmStats2 = rfm2[["Segment","Recency","Frequency", "Monetary"]].groupby("Segment").agg(["mean","median","count", "std"])
rfmStats2.columns = rfmStats2.columns.map('_'.join).str.strip('|')
rfmStats2
# Out:
#                      Recency_mean  Recency_median  Recency_count  Recency_std  \
# Segment
# About to Sleep              51.37           51.00            353        10.97
# At Risk                    152.04          137.00            594        68.64
# Can't Loose                130.05          105.00             64        65.15
# Champions                    4.37            3.00            632         3.68
# Hibernating                215.66          217.00           1069        92.04
# Loyal Customers             31.69           28.00            820        15.60
# Need Attention              50.27           50.00            184        11.53
# New Customers                5.43            6.00             42         3.90
# Potential Loyalists         15.37           16.00            486         9.34
# Promising                   21.42           21.00             95         5.24
#
#                      Frequency_mean  Frequency_median  Frequency_count  \
# Segment
# About to Sleep                 1.16              1.00              353
# At Risk                        2.87              3.00              594
# Can't Loose                    8.31              7.00               64
# Champions                     12.34              8.00              632
# Hibernating                    1.10              1.00             1069
# Loyal Customers                6.44              5.00              820
# Need Attention                 2.32              2.00              184
# New Customers                  1.00              1.00               42
# Potential Loyalists            2.01              2.00              486
# Promising                      1.00              1.00               95
#
#                      Frequency_std  Monetary_mean  Monetary_median  \
# Segment
# About to Sleep                0.37         472.55           331.95
# At Risk                       0.94        1079.81           675.16
# Can't Loose                   4.14        2791.01          2236.74
# Champions                    16.37        6866.78          2613.85
# Hibernating                   0.30         488.86           293.00
# Loyal Customers               4.45        2862.89          1737.83
# Need Attention                0.47         894.49           637.77
# New Customers                 0.00         388.21           274.50
# Potential Loyalists           0.65        1041.34           524.00
# Promising                     0.00         290.91           219.00
#
#                      Monetary_count  Monetary_std
# Segment
# About to Sleep                  353        532.93
# At Risk                         594       2559.61
# Can't Loose                      64       2074.24
# Champions                       632      20354.66
# Hibernating                    1069       2421.94
# Loyal Customers                 820       6003.49
# Need Attention                  184       1110.27
# New Customers                    42        570.78
# Potential Loyalists             486       7640.53
# Promising                        95        241.02

# %% [markdown]
# <a id='visualize'></a>
# <h1 style="color:purple" >6. Visualize</h1>

# %%
plt.figure(figsize = (25,8))
squarify.plot(sizes=rfmStats1.Recency_count, label=rfmStats1.index, 
              color=["red","orange","blue", "forestgreen", "yellow", "purple", "cornsilk","royalblue", "pink", "brown"], alpha=.4 )
plt.suptitle("Treemap: Number of Customers \n 2009-2010", fontsize=25);

# %%
plt.figure(figsize = (25,8))
squarify.plot(sizes=rfmStats2.Recency_count, label=rfmStats2.index, 
              color=["red","orange","blue", "forestgreen", "yellow", "purple", "cornsilk","royalblue", "pink", "brown"], alpha=.4 )
plt.suptitle("Treemap: Number of Customers \n 2010-2011", fontsize=25);
